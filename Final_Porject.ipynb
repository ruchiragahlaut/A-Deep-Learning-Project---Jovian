# %%
# Jovian Commit Essentials
# Please retain and execute this cell without modifying the contents for `jovian.commit` to work
# !pip install jovian --upgrade -q
import jovian
jovian.set_project('final-porject')
jovian.set_colab_id('1yZuCB1Hpp6SvpnvHTTNDIdpvszWxghiw')

# %%
# !pip install jovian --upgrade -q
import jovian
# Out:
#      |████████████████████████████████| 71kB 2.7MB/s
# ...

# %%
import numpy
import cv2
import random
import matplotlib.pyplot as plt
import pickle
import os
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor
import torch

# %%
project_name = 'new_project'

# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
from torchvision.datasets import CIFAR10
from torchvision.transforms import ToTensor
from torchvision.utils import make_grid
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import random_split
# %matplotlib inline

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-accc93ac-f6bf-43ad-b658-6b85708faf92" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-accc93ac-f6bf-43ad-b658-6b85708faf92">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"ruchiragahlautmunmun","key":"e7486f2790cf41a5a463c50fe9386aba"}'}

# %%
#! mkdir ~/.kaggle

#! chmod 600 ~/.kaggle/kaggle.json
#! cp kaggle.json ~/.kaggle/
! kaggle datasets list
# Out:
# ...
# ref                                                    title                                                size  lastUpdated          downloadCount
# -----------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# gpreda/covid-world-vaccination-progress                COVID-19 World Vaccination Progress                  39KB  2021-01-30 11:46:26           4277
# ayushggarg/all-trumps-twitter-insults-20152021         All Trump's Twitter insults (2015-2021)             581KB  2021-01-20 16:51:05            835
# sevgisarac/temperature-change                          Temperature change                                  778KB  2020-12-24 20:06:36            903
# jorgesandoval/wind-power-generation                    Wind Power Generation Data                          245KB  2021-01-07 18:45:08            368
# ...

# %%
# !kaggle datasets download -d arpitjain007/dog-vs-cat-fastai
# Out:
# ...
#  99% 1.58G/1.60G [00:13<00:00, 111MB/s]
# 100% 1.60G/1.60G [00:13<00:00, 127MB/s]

# %%
! unzip dog-vs-cat-fastai.zip -d dog-vs-cat-fastai
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dog-vs-cat-fastai/dogscats/train/dogs/dog.7066.jpg
#   inflating: dog-vs-cat-fastai/dogscats/train/dogs/dog.7067.jpg
#   inflating: dog-vs-cat-fastai/dogscats/train/dogs/dog.7068.jpg
#   inflating: dog-vs-cat-fastai/dogscats/train/dogs/dog.7069.jpg
#   inflating: dog-vs-cat-fastai/dogscats/train/dogs/dog.707.jpg
#   inflating: dog-vs-cat-fastai/dogscats/train/dogs/dog.7070.jpg
#   inflating: dog-vs-cat-fastai/dogscats/train/dogs/dog.7071.jpg
#   inflating: dog-vs-cat-fastai/dogscats/train/dogs/dog.7072.jpg
#   inflating: dog-vs-cat-fastai/dogscats/train/dogs/dog.7073.jpg
#   inflating: dog-vs-cat-fastai/dogscats/train/dogs/dog.7074.jpg
#   inflating: dog-vs-cat-fastai/dogscats/train/dogs/dog.7075.jpg
#   inflating: dog-vs-cat-fastai/dogscats/train/dogs/dog.7076.jpg
#   inflating: dog-vs-cat-fastai/dogscats/train/dogs/dog.7077.jpg
#   inflating: dog-vs-cat-fastai/dogscats/train/dogs/dog.7078.jpg
# ...

# %%
#dataset of cats and dogs
dir = "/content/dog-vs-cat-fastai/dogscats/train"
dir1 = "/content/dog-vs-cat-fastai/dogscats/test1"
categories = ['cats','dogs']

# %%
#transform data from array to tensor
import torchvision.transforms as transforms
transform = transforms.Compose([transforms.Resize((100,100)), transforms.ToTensor()])

# %%
from PIL import Image
img_size = 100
data = []
for i in categories:
  folder = os.path.join(dir,i)
  label = categories.index(i)
  for img in os.listdir(folder):
    img_path = os.path.join(folder,img)
    img_pil = Image.open(img_path)
    #img_arr = cv2.resize(img_arr,(img_size,img_size))
    img_arr = transform(img_pil)
    #plt.imshow(img_arr)
    data.append([img_arr,label])

# %%
from PIL import Image
img_size = 100
test_data = []
folder = dir1
for img in os.listdir(folder):
  img_path = os.path.join(folder,img)
  img_pil = Image.open(img_path)
  #img_arr = cv2.resize(img_arr,(img_size,img_size))
  img_arr = transform(img_pil)
  #plt.imshow(img_arr)
  test_data.append([img_arr,label])

# %%
#length of data
print(len(data))
print(len(test_data))
# Out:
# 23000
# 12500

# %%
random.shuffle(data)
# shuffle the data

# %%
#you can show the image
img,label = data[0]
print(img,label)
# Out:
# tensor([[[0.1412, 0.1412, 0.1412,  ..., 0.6235, 0.6118, 0.6118],
#          [0.1451, 0.1451, 0.1451,  ..., 0.6196, 0.6118, 0.6118],
#          [0.1333, 0.1373, 0.1490,  ..., 0.6196, 0.6118, 0.6196],
#          ...,
#          [0.0471, 0.0667, 0.0824,  ..., 0.4902, 0.4510, 0.3686],
#          [0.0549, 0.0667, 0.0824,  ..., 0.4902, 0.4471, 0.3725],
#          [0.0667, 0.0667, 0.0706,  ..., 0.4824, 0.4314, 0.3686]],
#
#         [[0.1804, 0.1804, 0.1804,  ..., 0.5922, 0.5804, 0.5804],
#          [0.1843, 0.1843, 0.1843,  ..., 0.5882, 0.5804, 0.5804],
#          [0.1765, 0.1765, 0.1882,  ..., 0.5882, 0.5804, 0.5882],
#          ...,
#          [0.0941, 0.1020, 0.0980,  ..., 0.4275, 0.3843, 0.3059],
#          [0.0980, 0.0980, 0.0980,  ..., 0.4275, 0.3804, 0.3059],
#          [0.0902, 0.0863, 0.0863,  ..., 0.4196, 0.3765, 0.3098]],
#
#         [[0.2275, 0.2275, 0.2275,  ..., 0.5176, 0.5059, 0.5059],
#          [0.2314, 0.2314, 0.2314,  ..., 0.5137, 0.5059, 0.5059],
# ...

# %%
#show the size and label
img, label = data[0]
plt.imshow(img.permute((1, 2, 0)))
print('Label (numeric):', label)
print(img.shape)
# Out:
# Label (numeric): 1
# torch.Size([3, 100, 100])

# %%
import torch
torch.manual_seed(43)
val_size = 6000
train_size = len(data) - val_size

# %%
#split the data
train_ds, val_ds = random_split(data, [train_size, val_size])
len(train_ds), len(val_ds)
# Out:
# (17000, 6000)

# %%
#define the size
batch_size=128

# %%
#train , validation and testing 
train_loader = DataLoader(train_ds, batch_size, shuffle=True, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_ds, batch_size*2, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_data, batch_size*2, num_workers=4, pin_memory=True)

# %%
# let see the grid the image
for images, _ in train_loader:
    print('images.shape:', images.shape)
    plt.figure(figsize=(16,8))
    plt.axis('off')
    plt.imshow(make_grid(images, nrow=16).permute((1, 2, 0)))
    break
# Out:
# images.shape: torch.Size([128, 3, 100, 100])

# %%
# shape of image
images.shape
# Out:
# torch.Size([128, 3, 100, 100])

# %%
#accuracy
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

# %%
#imageclassification
class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], val_loss: {:.4f}, val_acc: {:.4f}".format(epoch, result['val_loss'], result['val_acc']))

# %%
# evalution of model
def evaluate(model, val_loader):
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def fit(epochs, lr, model, train_loader, val_loader, opt_func=torch.optim.SGD):
    history = []
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase 
        for batch in train_loader:
            loss = model.training_step(batch)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        # Validation phase
        result = evaluate(model, val_loader)
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
torch.cuda.is_available()
# Out:
# False

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

# %%
device = get_default_device()
device
# Out:
# device(type='cpu')

# %%
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
def plot_losses(history):
    losses = [x['val_loss'] for x in history]
    plt.plot(losses, '-x')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Loss vs. No. of epochs');

# %%
def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs');

# %%
train_loader = DeviceDataLoader(train_loader, device)
val_loader = DeviceDataLoader(val_loader, device)
test_loader = DeviceDataLoader(test_loader, device)

# %%
input_size = 3*100*100
output_size = 2
hidden_size1 = 152
hidden_size2= 128
hidden_size3= 64

# %%
class catdog(ImageClassificationBase):
    def __init__(self):
        super().__init__()
        #hidden layer1
        self.linear1 = nn.Linear(input_size,hidden_size1)
        #hidden layer2
        self.linear2 = nn.Linear(hidden_size1,hidden_size2)
        #hidden layer
        #self.linear3 = nn.Linear(hidden_size2,hidden_size3)
        #hidden layer
        self.linear3 = nn.Linear(hidden_size2,hidden_size3)
        #output layer
        self.linear4 = nn.Linear(hidden_size3,output_size)

    def forward(self, xb):
        # Flatten images into vectors
        out = xb.view(xb.size(0), -1)
        # Apply layers & activation functions
        out = self.linear1(out)
        out = F.relu(out)
        out = self.linear2(out)
        out = F.relu(out)
        out = self.linear3(out)
        out = F.relu(out)
        out = self.linear4(out)
        #out = F.relu(out)
        #out = self.linear5(out)
        return out

# %%
model = to_device(catdog(), device)

# %%
history = [evaluate(model, val_loader)]
history
# Out:
# [{'val_acc': 0.4980003833770752, 'val_loss': 0.6950979828834534}]

# %%
history += fit(5,0.005, model, train_loader, val_loader)
# Out:
# Epoch [0], val_loss: 0.6855, val_acc: 0.5709
# Epoch [1], val_loss: 0.6800, val_acc: 0.5899
# Epoch [2], val_loss: 0.6746, val_acc: 0.5948
# Epoch [3], val_loss: 0.6695, val_acc: 0.6025
# Epoch [4], val_loss: 0.6688, val_acc: 0.5828

# %%
history += fit(5,0.05, model, train_loader, val_loader)
# Out:
# Epoch [0], val_loss: 0.6680, val_acc: 0.5938
# Epoch [1], val_loss: 0.6560, val_acc: 0.6130
# Epoch [2], val_loss: 0.6581, val_acc: 0.6066
# Epoch [3], val_loss: 0.6486, val_acc: 0.6280
# Epoch [4], val_loss: 0.6415, val_acc: 0.6274

# %%
plot_losses(history)
#let se the history of loss

# %%
plot_accuracies(history)
# let see the accuracy

# %%
evaluate(model, test_loader)
#final evalution of model
# Out:
# {'val_acc': 0.6040623784065247, 'val_loss': 0.6782547235488892}

# %%
# summary

# %% [markdown]
# In this dog and cat classification, i have learnt about the layers of CNN model. It was a great working experience with jovian. Thank You !!
